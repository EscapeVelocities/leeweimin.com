# %%
import pandas as pd

# %%
pd.read_excel('Doctors_Per_10,000_Total_Population.xlsx', header=5, index_col=0, nrows=4)
# Out:
#                                                   1960 1961 1962 1963 1964  \
# Variables
# Doctors Per 10,000 Total Population (Number)         4    4    4    4    5
# Dentists Per 10,000 Total Population (Number)        2    2    2    2    2
# Nurses Per 10,000 Total Population (Number)         na   na   na   na   na
# Per Capita Government Health Expenditure (Dollar)   na   na   na   na   na
#
#                                                   1965 1966 1967 1968 1969  \
# Variables
# Doctors Per 10,000 Total Population (Number)         5    5    6    6    7
# Dentists Per 10,000 Total Population (Number)        2    2    2    2    2
# Nurses Per 10,000 Total Population (Number)         na   na   na   na   na
# Per Capita Government Health Expenditure (Dollar)   na   na   na   na   na
#
#                                                   ...  2008 2009 2010 2011  \
# Variables                                         ...
# ...
