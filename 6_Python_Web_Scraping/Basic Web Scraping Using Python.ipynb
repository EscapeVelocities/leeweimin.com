# %%
import requests
from bs4 import BeautifulSoup

# %%
william_shakespeare_response = requests.get('https://openlibrary.org/authors/OL9388A/William_Shakespeare')

# %%
william_shakespeare_response
# Out:
# <Response [200]>

# %%
william_shakespeare_response.text
# Out:
# '\n\n<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en">\n<head>\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n    <meta name="title" content="" />\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    \n    <meta name="author" content="OpenLibrary.org" />\n    <meta name="creator" content="OpenLibrary.org" />\n    <meta name="copyright" content="Original content copyright; 2007-2015" />\n    <meta name="distribution" content="Global" />\n\n    <link rel="canonical" href="https://openlibrary.org/authors/OL9388A/William_Shakespeare" />\n\n    <link href="/static/images/openlibrary-120x120.png" rel="apple-touch-icon" />\n    <link href="/static/images/openlibrary-152x152.png" rel="apple-touch-icon" sizes="152x152" />\n    <link href="/static/images/openlibrary-167x167.png" rel="apple-touch-icon" sizes="167x167" />\n    <link href="/static/images/openlibrary-180x180.png" rel="apple-touch-icon" sizes="180x180" 
# ...

# %%
william_shakespeare_soup = BeautifulSoup(william_shakespeare_response.text, 'html.parser')

# %%
william_shakespeare_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="" name="title"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="OpenLibrary.org" name="author">
# <meta content="OpenLibrary.org" name="creator"/>
# <meta content="Original content copyright; 2007-2015" name="copyright"/>
# <meta content="Global" name="distribution"/>
# <link href="https://openlibrary.org/authors/OL9388A/William_Shakespeare" rel="canonical"/>
# <link href="/static/images/openlibrary-120x120.png" rel="apple-touch-icon"/>
# <link href="/static/images/openlibrary-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/static/images/openlibrary-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="/static/images/openlibrary-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
type(william_shakespeare_soup)
# Out:
# bs4.BeautifulSoup

# %%
william_shakespeare_html = william_shakespeare_soup.prettify()

# %%
print(william_shakespeare_html)
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="" name="title"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="OpenLibrary.org" name="author">
#    <meta content="OpenLibrary.org" name="creator"/>
#    <meta content="Original content copyright; 2007-2015" name="copyright"/>
#    <meta content="Global" name="distribution"/>
#    <link href="https://openlibrary.org/authors/OL9388A/William_Shakespeare" rel="canonical"/>
#    <link href="/static/images/openlibrary-120x120.png" rel="apple-touch-icon"/>
#    <link href="/static/images/openlibrary-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#    <link href="/static/images/openlibrary-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
#    <link href="/static/images/openlibrary-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# ...

# %%
william_shakespeare_soup_contentHead = william_shakespeare_soup.find('div', {'id':'contentHead'})

# %%
william_shakespeare_soup_contentHead
# Out:
# <div id="contentHead">
# <div class="edit" id="editTools">
# <div id="editButton">
# <a accesskey="e" class="linkButton larger" href="/authors/OL9388A/William_Shakespeare/edit" title="Edit this template">Edit</a>
# </div>
# <div id="editInfo">
# <div class="brown smaller sansserif">Last edited by <a href="/people/seabelis" rel="nofollow">Lisa</a></div>
# <div class="smallest gray sansserif">November 24, 2018 | <a href="/authors/OL9388A/William_Shakespeare?m=history" rel="nofollow" title="View this template's edit history">History</a></div>
# </div>
# </div>
# <h1>William Shakespeare</h1>
# <h2 class="author collapse">
#     April 20, 1564 - April 23, 1616
#     </h2>
# </div>

# %%
type(william_shakespeare_soup_contentHead)
# Out:
# bs4.element.Tag

# %%
william_shakespeare_soup_contentHead.h1.string
# Out:
# 'William Shakespeare'

# %%
william_shakespeare_soup_contentHead.h2.string.strip()
# Out:
# 'April 20, 1564 - April 23, 1616'

# %%
william_shakespeare_soup_contentTwothird = william_shakespeare_soup.find('div', {'class':'contentTwothird'})

# %%
william_shakespeare_soup_contentTwothird
# Out:
# <div class="contentTwothird" style="margin-bottom:0;">
# <p>William Shakespeare was an English poet and playwright, widely regarded as the greatest writer in the English language and the world's pre-eminent dramatist.  He is often called England's national poet and the "Bard of Avon".  His surviving works, including some collaborations, consist of 38 plays,[c]  154 sonnets, two long narrative poems, and several other poems. His plays have been translated into every major living language and are performed more often than those of any other playwright.  (<a href="http://en.wikipedia.org/wiki/William_Shakespeare" rel="nofollow">Source</a>.)
# </p>
# <div class="clearfix"></div>
# <div class="section" id="works">
# <h2 class="collapse">
#                     10,087 works
#                     <span class="count smaller"><a href="/books/add?author=/authors/OL9388A">Add another</a>?</span>
# </h2>
# <p id="books"><span class="tools">
# ...

# %%
william_shakespeare_soup_contentTwothird.p.contents[0].strip()
# Out:
# 'William Shakespeare was an English poet and playwright, widely regarded as the greatest writer in the English language and the world\'s pre-eminent dramatist.  He is often called England\'s national poet and the "Bard of Avon".  His surviving works, including some collaborations, consist of 38 plays,[c]  154 sonnets, two long narrative poems, and several other poems. His plays have been translated into every major living language and are performed more often than those of any other playwright.  ('

# %%
book_titles = william_shakespeare_soup.find_all('h3', {'class':'booktitle'})

# %%
type(book_titles)
# Out:
# bs4.element.ResultSet

# %%
book_titles
# Out:
# [<h3 class="booktitle">
#  <a class="results" href="/works/OL15203981W" itemprop="name">Hamlet</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362699W" itemprop="name">The Tempest</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362705W" itemprop="name">Romeo and Juliet</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL15203980W" itemprop="name">Macbeth</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362704W" itemprop="name">King Lear</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362700W" itemprop="name">Othello</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362702W" itemprop="name">Julius Caesar</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362706W" itemprop="name">Sonnets</a>
#  </h3>, <h3 class="booktitle">
#  <a class="results" href="/works/OL362703W" itemprop="name">Midsummer night's dream</a>
# ...

# %%
for book_title in book_titles:
    print(book_title.a.string)
# Out:
# Hamlet
# The Tempest
# Romeo and Juliet
# Macbeth
# King Lear
# Othello
# Julius Caesar
# Sonnets
# Midsummer night's dream
# Twelfth night
# Henry V
# As you like it
# Antony and Cleopatra
# King Richard III
# Much ado about nothing
# Tragedies
# Henry IV
# King Richard II
# Coriolanus
# Taming of the shrew
# King Henry VI Part II
# Winter's tale
# Love's Labour's lost
# King John
# Cymbeline
# Troilus and Cressida
# King Henry VIII
# All's well that ends well
# Timon of Athens
# Comedy of errors
# Pericles
# Merry wives of Windsor
# Titus Andronicus
# Poems
# Collected works
# Two gentlemen of Verona
# Works (Hudson)
# The complete works
# The works of Shakespeare
# King Lear
# The winter's tale
# Twelfth night
# The two gentlemen of Verona
# Venus and Adonis
# Shakespeare
# The two noble kinsmen
# The complete works of Shakespeare
# William Shakespeare
# King Henry IV. Part 1
# The Plays of William Shakespeare
# Julius Cæsar
# The Two Noble Kinsmen
# ...
