# %%
import pandas as pd

# %%
pd.read_csv(r'Doctors_Per_10000_Total_Population.csv', index_col=0)
# Out:
#       doctors_per_10000_total_population
# year
# 1960                                   4
# 1961                                   4
# 1962                                   4
# 1963                                   4
# 1964                                   5
# 1965                                   5
# 1966                                   5
# 1967                                   6
# 1968                                   6
# 1969                                   7
# 1970                                   7
# 1971                                   7
# 1972                                   7
# 1973                                   7
# 1974                                   7
# 1975                                   7
# 1976                                   7
# 1977                                   8
# 1978                                   8
# 1979                                   8
# 1980                                   8
# 1981                                   8
# ...
